# %%
print("hello")
# Out:
# hello

# %%
a = 30
b = a
if a>b:
    print("A > B")
elif a == b :
    print("A == B")
else :
    print("B > A")
# Out:
# A == B

# %%
fruits = ["Apple", "Banana", "Mango"]
fruits[0] = 2
print(fruits[0])
# Out:
# 2

# %%
mu_list = list(("qdqaqwdwq","v"))
mu_tuple = tuple(mu_list)


mu_list[0] = "dd"
print(len(mu_list[0]))
# Out:
# 6

# %%
fruits = {"Apple", "Banana", "Mango"}
i = 0
while i < len(fruits):
    print(fruits[i])
    i += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 fruits = {"Apple", "Banana", "Mango"}
#       2 i = 0
#       3 while i < len(fruits):
# ----> 4     print(fruits[i])
#       5     i += 1
#
# TypeError: 'set' object is not subscriptable

# %%
student = {1:3}
print((student))
# Out:
# {1: 3}

# %%
class Student:
    namew = "sasadcdsc"

>>>        pass
    def __init__(self, fullName):
        self.nascdscme = fullName
        print(self.nascdscme)

s1 = print(Student.namew)
# Out:
# sasadcdsc

# %%
import numpy as  np

a  = np.array([[1,2,3], [4,5,6]])
print(a[0])
# Out:
# [1 2 3]
